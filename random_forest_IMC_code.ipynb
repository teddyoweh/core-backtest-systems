# %%
import json
from typing import Dict, List
from json import JSONEncoder
import jsonpickle
import numpy as np 
from sklearn.ensemble import RandomforestRegressor
from datamodel import TradingState, Observation, order

Time = int
Symbol = str
symbol = str
Position = int
UserId = str
Observation = int

def train_model()
#train the random forest model using sandbox logs
class Listing:
    def __init__(self, symbol: Symbol, symbol: symbol, denomination: symbol):
        self.symbol = symbol
        self.symbol = symbol
        self.denomination = denomination

class Order:
    def __init__(self, symbol: Symbol, price: int, quantity: int) -> None:
        self.symbol = symbol
        self.price = price
        self.quantity = quantity

    def __str__(self) -> str:
        return "(" + self.symbol + ", " + str(self.price) + ", " + str(self.quantity) + ")"

    def __repr__(self) -> str:
        return "(" + self.symbol + ", " + str(self.price) + ", " + str(self.quantity) + ")"
    

class OrderDepth:
    def __init__(self):
        self.buy_orders: Dict[int, int] = {}
        self.sell_orders: Dict[int, int] = {}

class Trade:
    self.model = RandomForestReggresor(n_estimators=100, random_state=52)
    def __init__(self, symbol: Symbol, price: int, quantity: int, buyer: UserId = None, seller: UserId = None, timestamp: int = 0) -> None:
        self.symbol = symbol
        self.price: int = price
        self.quantity: int = quantity
        self.buyer = buyer
        self.seller = seller
        self.timestamp = timestamp

class TradingState(object):
    def __init__(self,
                 timestamp: Time,
                 listings: Dict[Symbol, Listing],
                 order_depths: Dict[Symbol, OrderDepth],
                 own_trades: Dict[Symbol, List[Trade]],
                 market_trades: Dict[Symbol, List[Trade]],
                 position: Dict[symbol, Position],
                 observations: Dict[symbol, Observation]):
        self.timestamp = timestamp
        self.listings = listings
        self.order_depths = order_depths
        self.own_trades = own_trades
        self.market_trades = market_trades
        self.position = position
        self.observations = observations
    def preprocess_data(self, state: TradingState):
        
        features []
        for symbol in state.order_depths:
            order_depths = state.order_depbths[symbol]
            if symbol in state.postiion:
                position = state.position[symbol]
                #extract features (ema) from the order depths and postion
                     features.append([len(order_depth.buy_orders), len(order_depth.sell_orders), position])
        return np.array(features)
    def toJSON(self):
        return json.dumps(self, default=lambda o: o.__dict__, sort_keys=True)
    
class ProsperityEncoder(JSONEncoder):
        def default(self, o):
            return o.__dict__

def gemerate_features_andlabels(states: List[TradingState]) -> (np.array, np.array):

features = [ema]

for state in states:
    class ConversionObservation:

    def __init__(self, bidPrice: float, askPrice: float, transportFees: float, exportTariff: float, importTariff: float, sunlight: float, humidity: float):
        self.bidPrice = bidPrice
        self.askPrice = askPrice
        self.transportFees = transportFees
        self.exportTariff = exportTariff
        self.importTariff = importTariff
        self.sunlight = sunlight
        self.humidity = humidity
        

class Observation:

    def __init__(self, plainValueObservations: Dict[symbol, ObservationValue], conversionObservations: Dict[symbol, ConversionObservation]) -> None:
        self.plainValueObservations = plainValueObservations
        self.conversionObservations = conversionObservations
        
    def __str__(self) -> str:
        return "(plainValueObservations: " + jsonpickle.encode(self.plainValueObservations) + ", conversionObservations: " + jsonpickle.encode(self.conversionObservations) + ")"

        fair_values = self.predict_fair_values (X) 
    result = {}
     for idx, symbol in enumerate(state.order_depths):
            order_depth = state.order_depths[symbol]
            if symbol in state.position:
                position = state.position[symbol]
                fair_value = fair_values[idx]
                if symbol == "STARFRUIT" and len(order_depth.sell_orders) > 0:
                    best_ask, best_ask_amount = list(order_depth.sell_orders.items())[0]
                    if best_ask < fair_value and position < 10:
                        max_buy_quantity = min(-best_ask_amount, 10 - position)
                        orders.append(Order(symbol, best_ask, max_buy_quantity))
                elif symbol == "AMETHYSTS" and len(order_depth.buy_orders) > 0:
                    best_bid, best_bid_amount = list(order_depth.buy_orders.items())[0]
                    if best_bid > fair_value:
                        max_sell_quantity = min(best_bid_amount, 20 + position)
                        orders.append(Order(symbol, best_bid, -max_sell_quantity))
            result[symbol] = orders
        
        traderData = "SAMPLE" 
        conversions = 1
        return result, conversions, traderData
